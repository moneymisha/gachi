# %% [markdown]
# Создание графика функции

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import numpy as np
import sympy
from sympy import diff
import matplotlib.pyplot as plt

n = 1
x = np.linspace(-10, 10, 50) #значения х (наим, наиб, число точек)
y = n*x**3 + n**2*x**2 +n**3*x+n**4 
y1 = 3*n*x**2 + 2*n*2*x + 3*n**2*x+4*n**3 #производная
y2 = 6*n*x + 4*n*x + 6*n*x + 12*n**2 #2 производная

fig, ax = plt.subplots () #фигура и оси
plt.plot(x, y, color = "blue", label = "y(x)") 
plt.plot(x, y1, color = "red", label = "y'(x)") #cтроим график производной (аргумент, значение, цвет, подпись)
plt.plot(x, y2, color = "yellow", label = "y''(x)")
ax.set_xlabel ("x") #ось x
ax.set_ylabel ("y") #ось y
ax.grid(True) #добавление сетки
plt.legend ()

# %% [markdown]
# Создание фигуры

# %%
fig = plt.figure (figsize=(10,10)) #создание осей
ax_3d = fig.add_subplot(projection='3d')

a = np.linspace (0, 2*np.pi, 100) #создание массива от 0 до 2 пи с шагом 100
b = np.linspace (0,np.pi,100)

x = 10 * np.outer(np.cos(a), np.sin(b)) #произведение 2-х векторов
y = 10 * np.outer(np.sin(a), np.sin(b))
z = 10 * np.outer(np.ones(np.size(a)), np.cos(b))

ax_3d.plot_surface(x, y, z, rstride=4, cstride=4, color='green')

plt.show()

# %%
fig = plt.figure (figsize=(10,10)) #создание осей
ax_3d = fig.add_subplot(projection='3d')

a = np.linspace (0, 100, 50) 
b = np.linspace (0, 100, 50)

x = 5*np.outer(a,a)
y = 5* np.outer(b,b)
R = 5
z = np.outer (x,y)

ax_3d.plot_surface(x, y, z, rstride=10, cstride=14, color='green')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ageevmm\Desktop\labs\графики.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/ageevmm/Desktop/labs/%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> y = 5* np.outer(b,b)
#       <a href='vscode-notebook-cell:/c%3A/Users/ageevmm/Desktop/labs/%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> z = np.outer (x,y)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ageevmm/Desktop/labs/%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> ax_3d.plot_surface(x, y, z, rstride=10, cstride=14, color='green')
#      <a href='vscode-notebook-cell:/c%3A/Users/ageevmm/Desktop/labs/%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> plt.show()
#
# File c:\Users\ageevmm\AppData\Local\anaconda3\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1572, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1569     raise ValueError("Argument Z must be 2-dimensional.")
#    1571 Z = cbook._to_unmasked_float_array(Z)
# -> 1572 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#    1573 rows, cols = Z.shape
#    1575 has_stride = 'rstride' in kwargs or 'cstride' in kwargs
#
# File <__array_function__ internals>:200, in broadcast_arrays(*args, **kwargs)
#
# File c:\Users\ageevmm\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File c:\Users\ageevmm\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (50, 50) and arg 2 with shape (2500, 2500).

# %%
y =  1 - (5/6)**10
y
# Out:
# 0.8384944171101543
